# %% [markdown]
# # Maths behind ML

# %%
import numpy as np

# %%
a = np.array([3,4,5])

# %%
b = np.array([1,3,6])

# %%
np.dot(a,b)
# Out:
# 45

# %%
x = np.matrix([[1,2,3,4],[5,6,7,8],[2,3,4,5],[6,7,8,9]])
x
# Out:
# matrix([[1, 2, 3, 4],
#         [5, 6, 7, 8],
#         [2, 3, 4, 5],
#         [6, 7, 8, 9]])

# %%
x.shape
# Out:
# (4, 4)

# %%
m1 = np.matrix([[1,2,3],[4,5,6]])
m1
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6]])

# %%
m2 = np.matrix([[7,8],[9,10],[11,12]])
m2
# Out:
# matrix([[ 7,  8],
#         [ 9, 10],
#         [11, 12]])

# %%
m1.shape, m2.shape
# Out:
# ((2, 3), (3, 2))

# %%
m1*m2 # matrix multiplication
# Out:
# matrix([[ 58,  64],
#         [139, 154]])

# %%
from numpy import linalg as LA

# %%
y1 = np.matrix([[1,2,3],[4,5,6],[7,8,9]])
y1
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
LA.matrix_rank(y1) #rank of a matrix => no. of linearly independent rows/column
# Out:
# 2

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ## 1. Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(5,100,100)
y = np.linspace(10,1000,100)
plt.plot(x,y)

# %%
plt.plot([1,4,6,8],[3,8,3,5]) # [x1,x2,x3,x4] [y1,y2,y3,y4]

# %%
plt.plot([2,3],[3,3])
plt.plot([3,3],[3,5])
plt.plot([2,3],[3,5])

# %%
plt.plot(x,y)

plt.xlabel("x-axis ->")
plt.ylabel("y-axis ->")
plt.title("Title")

plt.xlim([20,80])
plt.ylim([200,800])
plt.show()

# %%
a = np.linspace(1,20,10)
b = a**2.5
c = a**3
d = np.log(a)
plt.plot(a,b,"b+",a,c,"g^",a,d,"r-")

# %% [markdown]
# ### Subplots

# %%
x1 = np.linspace(1,10,100)
y1 = np.log(x1)

plt.figure(1)

plt.subplot(121)
plt.title("y = log(x)")
plt.plot(x1,y1)

plt.subplot(122)
plt.title("y = log(x)**2")
plt.plot(x1,y1**2)
plt.show()

# %%
x2 = np.linspace(0.1,10,50)

plt.figure(1)

plt.subplot(221)
plt.title("Linear")
plt.plot(x2,x2)

plt.subplot(222)
plt.title("Cubic")
plt.plot(x2,x2**3)

plt.figure(2)

plt.subplot(221)
plt.title("Log")
plt.plot(x2,np.log(x2))

plt.subplot(222)
plt.title("Exponential")
plt.plot(x2,x2**x2)

# %% [markdown]
# ### Common Plots
#
# 1. BoxPlots <br>
# 2. Histograms <br>
# 3. Scatter Plots <br>
# 4. Bar Plots

# %%
df = pd.read_csv("./global_sales_data/market_fact.csv")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# ### 1. BoxPlots

# %%
plt.boxplot(df["Order_Quantity"])
plt.show()

# %%
df["Order_Quantity"].describe()
# Out:
# count    8399.000000
# mean       25.571735
# std        14.481071
# min         1.000000
# 25%        13.000000
# 50%        26.000000
# 75%        38.000000
# max        50.000000
# Name: Order_Quantity, dtype: float64

# %%
plt.boxplot(df["Sales"])
plt.show()

# %%
df["Sales"].describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %%
plt.subplot(121)
plt.boxplot(df["Sales"]) # difficult to read bcoz of large variations in y-axis values

plt.subplot(122)
plt.boxplot(df["Sales"])
plt.yscale("log")  # so scaling y-axis so that data becomes more readable.
plt.show()

# %%
df["Sales"].describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %% [markdown]
# ### 2. Histogram

# %%
plt.hist(df["Sales"])
plt.show()

# %%
plt.hist(df["Sales"])
plt.yscale("log")

# %% [markdown]
# ### 3. Scatter Plot
#
# useful to visualize two variables

# %%
plt.scatter(df["Sales"],df["Profit"])
plt.show()

# %% [markdown]
# ### Reading Images
# Matplotlib stores image as an array.

# %%
image = plt.imread("download.jpg")
plt.imshow(image)
plt.show()

# %%
print(type(image))
print(image.shape)
print(image.dtype)
# Out:
# <class 'numpy.ndarray'>
# (168, 300, 3)
# uint8

# %% [markdown]
# The 3rd dimension is for color, the RGB values.

# %%
image
# Out:
# array([[[ 23,  24,  29],
#         [ 23,  24,  29],
#         [ 23,  24,  29],
#         ...,
#         [ 71,  77,  91],
#         [ 71,  77,  91],
#         [ 71,  77,  93]],
#
#        [[ 24,  25,  30],
#         [ 24,  25,  30],
#         [ 24,  25,  30],
#         ...,
#         [ 67,  73,  87],
#         [ 66,  72,  86],
#         [ 66,  72,  88]],
#
#        [[ 24,  25,  30],
#         [ 24,  25,  30],
#         [ 24,  25,  30],
#         ...,
#         [ 81,  87, 101],
#         [ 80,  86, 100],
#         [ 80,  86, 102]],
#
#        ...,
#
#        [[ 29,  32,  41],
#         [ 29,  32,  41],
#         [ 30,  33,  42],
#         ...,
#         [ 27,  27,  35],
#         [ 27,  27,  35],
#         [ 28,  28,  36]],
#
#        [[ 28,  31,  40],
#         [ 28,  31,  40],
#         [ 29,  32,  41],
#         ...,
#         [ 27,  27,  35],
#         [ 27,  27,  35],
#         [ 28,  28,  36]],
#
#        [[ 27,  30,  39],
#         [ 27,  30,  39],
#         [ 28,  31,  40],
# ...

# %% [markdown]
# ## 2. Seaborn
# Built on top of ```matplotlib```, more concise and attractive.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sns.set_style("whitegrid")
df = pd.read_csv("./global_sales_data/market_fact.csv")

# %% [markdown]
# ### Histograms and density plots

# %%
sns.displot(df["Shipping_Cost"])
plt.show()

# %%
sns.displot(df["Shipping_Cost"][:200], rug = True)

# %%
sns.distplot(df["Sales"], hist = False)
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#boxplots
sns.boxplot(x = df["Order_Quantity"])
plt.show()

# %%
sns.boxplot(y = df["Order_Quantity"])
plt.show()

# %%
# joint plots => for two variables

sns.jointplot("Sales","Profit",df)
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = df[(df.Profit < 1000) & (df.Sales < 20000)]
sns.jointplot("Sales","Profit",df)
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = pd.read_csv("./global_sales_data/market_fact.csv")
df = df[(df.Profit < 100) & (df.Profit > -100) & (df.Sales < 200)]
sns.jointplot("Sales","Profit",df, kind = "hex", color = "k")
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Bottom-Right region represents orders where Sales is high but profit is negative.

# %% [markdown]
# ### Pairwise Plotting

# %%
btc = pd.read_csv("crypto_data/bitcoin_price.csv")
ether = pd.read_csv("crypto_data/ethereum_price.csv")
ltc = pd.read_csv("crypto_data/litecoin_price.csv")
monero = pd.read_csv("crypto_data/monero_price.csv")
neo = pd.read_csv("crypto_data/neo_price.csv")
quantum = pd.read_csv("crypto_data/qtum_price.csv")
ripple = pd.read_csv("crypto_data/ripple_price.csv")

btc.columns = btc.columns.map(lambda x: str(x) + "_btc")
ether.columns = ether.columns.map(lambda x: str(x) + "_et")
ltc.columns = ltc.columns.map(lambda x: str(x) + "_ltc")
monero.columns = monero.columns.map(lambda x: str(x) + "_mon")
neo.columns = neo.columns.map(lambda x: str(x) + "_neo")
quantum.columns = quantum.columns.map(lambda x: str(x) + "_qt")
ripple.columns = ripple.columns.map(lambda x: str(x) + "_rip")

btc.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc
# 0  117,056,000,000
# 1  123,379,000,000
# 2  123,388,000,000
# 3  119,376,000,000
# 4  118,084,000,000

# %%
m1 = pd.merge(btc,ether, how = "inner", left_on = "Date_btc", right_on = "Date_et")
m2 = pd.merge(m1, ltc, how = "inner", left_on = "Date_btc", right_on = "Date_ltc")
m3 = pd.merge(m2, monero, how = "inner", left_on = "Date_btc", right_on = "Date_mon")
m4 = pd.merge(m3, neo, how = "inner", left_on = "Date_btc", right_on = "Date_neo")
m5 = pd.merge(m4, quantum, how = "inner", left_on = "Date_btc", right_on = "Date_qt")
crypto = pd.merge(m5, ripple, how = "inner", left_on = "Date_btc", right_on = "Date_rip")

crypto.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc       Date_et  Open_et  High_et  ...  Close_qt  \
# 0  117,056,000,000  Nov 07, 2017   298.57   304.84  ...     11.21
# 1  123,379,000,000  Nov 06, 2017   296.43   305.42  ...     10.44
# 2  123,388,000,000  Nov 05, 2017   300.04   301.37  ...     10.13
# 3  119,376,000,000  Nov 04, 2017   305.48   305.48  ...     10.05
# 4  118,084,000,000  Nov 03, 2017   288.50   308.31  ...     10.38
#
#      Volume_qt Market Cap_qt      Date_rip  Open_rip  High_rip   Low_rip  \
# ...

# %%
curr = crypto[["Close_btc", "Close_et", "Close_ltc", "Close_mon","Close_neo", "Close_qt" ]]
curr.head()
# Out:
#    Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# 0    7144.38    294.66      61.30      99.76      26.23     11.21
# 1    7022.76    298.89      55.17     102.92      26.32     10.44
# 2    7407.41    296.26      54.75      86.35      26.38     10.13
# 3    7379.95    300.47      55.04      87.30      26.49     10.05
# 4    7207.76    305.71      56.18      87.99      26.82     10.38

# %%
#pair plot
sns.pairplot(curr)

# %%
# correlation (interdependence on each other) among currencies
cor = curr.corr()
round(cor,3)
# Out:
#            Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# Close_btc      1.000     0.449      0.658      0.697      0.735     0.382
# Close_et       0.449     1.000      0.490      0.539      0.482     0.791
# Close_ltc      0.658     0.490      1.000      0.793      0.641     0.448
# Close_mon      0.697     0.539      0.793      1.000      0.669     0.518
# Close_neo      0.735     0.482      0.641      0.669      1.000     0.557
# Close_qt       0.382     0.791      0.448      0.518      0.557     1.000

# %% [markdown]
# ### HeatMap
# Helpful to visualise correlation matrix

# %%
plt.figure(figsize=(10,8))

sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# All the dark colored values means high correlation. <br>
# High correlation => if one goes down other will also be impacted.<br>
# at the same time, if one goes up the other will too! <br>
# But it is always advisable to invest in low correlation entities (diverse investment).

# %% [markdown]
# # Case Study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style = "white")

market_df = pd.read_csv("./global_sales_data/market_fact.csv")
customer_df = pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("./global_sales_data/orders_dimen.csv")

# %%
sns.boxplot(y = market_df["Sales"])
plt.yscale("log")
plt.show()

# %%
df = pd.merge(market_df, product_df, how = "inner", on = "Prod_id")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# 0  -30.51           3.60                 0.56  OFFICE SUPPLIES
# 1   23.12           3.37                 0.57  OFFICE SUPPLIES
# 2  -17.58           3.98                 0.56  OFFICE SUPPLIES
# 3   61.57           3.14                 0.60  OFFICE SUPPLIES
# 4  -78.64           6.14                 0.59  OFFICE SUPPLIES
#
#             Product_Sub_Category
# 0  SCISSORS, RULERS AND TRIMMERS
# 1  SCISSORS, RULERS AND TRIMMERS
# ...

# %%
sns.boxplot(x = "Product_Category", y = "Sales", data = df)
plt.yscale("log")
plt.show()

# %%
sns.boxplot(x = "Product_Category", y = "Profit", data = df)
plt.show()

# %%
df = df[(df.Profit < 1000)&(df.Profit > -1000)]
sns.boxplot(x = "Product_Category", y = "Profit", data = df)
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.subplot(121)
sns.boxplot(x = "Product_Category", y = "Sales", data = df)
plt.title("Sales")
plt.yscale("log")

plt.subplot(122)
sns.boxplot(x = "Product_Category", y = "Profit", data = df)
plt.title("Profit")
plt.show()

# %%
df = pd.merge(df, customer_df, how = "inner", on = "Cust_id")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 3  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 4  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
#
#    Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# 0  -30.51           3.60                 0.56  OFFICE SUPPLIES
# 1    4.56           0.93                 0.54  OFFICE SUPPLIES
# 2  729.34          14.30                 0.37  OFFICE SUPPLIES
# 3  -47.64           6.15                 0.37  OFFICE SUPPLIES
# 4   23.12           3.37                 0.57  OFFICE SUPPLIES
#
#             Product_Sub_Category Customer_Name_x Province_x Region_x  \
# ...

# %%
sns.boxplot(x = "Customer_Segment_x", y = "Profit", data = df)
plt.show()

# %%
plt.figure(num=None, figsize = (12,8), dpi = 80, facecolor = "w", edgecolor = "k")
sns.boxplot(x = "Customer_Segment_x", y = "Profit", hue = "Product_Category", data=df)
plt.show()

# %%
sns.boxplot(x=df["Product_Category"], y=100*df["Shipping_Cost"]/df["Sales"])
plt.ylabel("100*(Shipping Cost/Sales)")
plt.show()

# %% [markdown]
# ## Bar Plots - Mean, Median and Count Plots
# Bar Plots used to display aggregated values of a variable rather than entire distributions.<br>
# useful when lot of data which is difficult to visualise in single figure.<br>

# %%
sns.barplot(x = "Product_Category", y = "Sales", data = df)
plt.show()

# %%
plt.figure(figsize = (12,6))

plt.subplot(121)
sns.barplot(x = "Product_Category", y = "Sales", data=df)
plt.title("Average Sales")

plt.subplot(122)
sns.barplot(x = "Product_Category", y = "Sales", data=df, estimator = np.median)
plt.title("Median Sales")
plt.show()

# %%
plt.figure(num=None, figsize=(12,8), dpi=80, facecolor="w", edgecolor = "k")
sns.barplot(x="Customer_Segment_x", y = "Profit", hue = "Product_Category", data=df, estimator = np.median)
plt.show()

# %% [markdown]
# => Technology is profitable in small buss and corporate <br>
# => Furniture is in loss in all segment

# %%
plt.figure(figsize = (10,8))
sns.barplot(x = "Profit", y = "Product_Sub_Category", data = df, estimator = np.median)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(y="Product_Sub_Category", data = df)
plt.show()

# %% [markdown]
# # Time Series

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df = pd.merge(market_df, orders_df, how = "inner", on = "Ord_id")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID  Order_Date  \
# 0   -30.51           3.60                 0.56     36262  27-07-2010
# 1  1148.90           2.50                 0.59     36262  27-07-2010
# 2   -47.64           6.15                 0.37     36262  27-07-2010
# 3     4.56           0.93                 0.54     20513  07-07-2009
# 4   729.34          14.30                 0.37     39682  09-11-2010
#
#   Order_Priority
# 0  NOT SPECIFIED
# 1  NOT SPECIFIED
# 2  NOT SPECIFIED
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
#  10  Order_ID             8399 non-null   int64
#  11  Order_Date           8399 non-null   object
#  12  Order_Priority       8399 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 918.6+ KB

# %%
# converting order date to datetime type
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
#  10  Order_ID             8399 non-null   int64
#  11  Order_Date           8399 non-null   datetime64[ns]
#  12  Order_Priority       8399 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 918.6+ KB

# %%
time_df = df.groupby("Order_Date")["Sales"].sum()
print(time_df.head())
print(type(time_df))
# Out:
# Order_Date
# 2009-01-01    1052.8400
# 2009-01-02    5031.9000
# 2009-01-03    7288.1375
# 2009-01-04    6188.4245
# 2009-01-05    2583.3300
# Name: Sales, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
# time series plot:
plt.figure(figsize = (16,8))
sns.lineplot(data = time_df) # earlier tsplot function was used.
plt.show()

# %%
df["month"] = df["Order_Date"].dt.month

df["year"] = df["Order_Date"].dt.year
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID Order_Date  \
# 0   -30.51           3.60                 0.56     36262 2010-07-27
# 1  1148.90           2.50                 0.59     36262 2010-07-27
# 2   -47.64           6.15                 0.37     36262 2010-07-27
# 3     4.56           0.93                 0.54     20513 2009-07-07
# 4   729.34          14.30                 0.37     39682 2010-09-11
#
#   Order_Priority  month  year
# 0  NOT SPECIFIED      7  2010
# 1  NOT SPECIFIED      7  2010
# ...

# %%
df_time = df.groupby(["year","month"]).Sales.mean()
df_time.head()
# Out:
# year  month
# 2009  1        1898.475090
#       2        2116.510723
#       3        2258.661599
#       4        2374.155868
#       5        1922.317055
# Name: Sales, dtype: float64

# %%
# creating pivot table for year-month wise sale
year_month = pd.pivot_table(df, values="Sales", index = "year", columns = "month")
year_month.head()
# Out:
# month           1            2            3            4            5   \
# year
# 2009   1898.475090  2116.510723  2258.661599  2374.155868  1922.317055
# 2010   1549.664361  1591.532297  1708.934944  1461.935539  1440.393540
# 2011   1321.671562  1733.378070  1822.860614  2062.716921  1822.033936
# 2012   2220.831551  2438.166961  1578.284028  1325.253694  1865.744629
#
# month           6            7            8            9            10  \
# year
# 2009   1548.093259  1909.084469  1827.095921  1717.295494  2203.961070
# 2010   1695.397085  1272.653408  1277.917503  2216.599136  1927.250907
# 2011   1655.599644  1515.576260  1471.700741  1430.616748  1851.404564
# 2012   2192.228263  1824.935942  1090.950643  1628.963780  1636.951775
#
# month           11           12
# year
# 2009   1502.192743  2209.047484
# 2010   1806.324648  1869.720956
# 2011   2161.479056  1672.187881
# 2012   1935.183039  1747.047528

# %%
plt.figure(figsize=(12,8))
sns.heatmap(year_month, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
